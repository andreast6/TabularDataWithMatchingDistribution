# %% [markdown]
# # Lending Club Loan Data Clustering & Seed Instruction Generation
#
# ## 📦 Environment Setup
# - Installs necessary libraries for data analysis

# %%
# !pip install -q hvplot

# %% [markdown]
# ## 📊 Data Loading & Preparation
# - Loads dataset from Lending Club loan data CSV
# - Performs train/test split (66%/34%) with random sampling
# - Handles data persistence through pickling for reproducibility

# %%
import hvplot.pandas
import pandas as pd
import numpy as np
SaveSplits=True
df = pd.read_csv("data_tab_separated-large_synthetic.csv")

data=df.dropna()

import random
import pickle
#train, test,  = train_test_split(data2, test_size=0.33, random_state=42)
Corrs=True
random.seed(42)
Ind=list(range(len(data)))
random.shuffle(Ind)
trainInd=Ind[:int(0.66*len(data))]
testInd=Ind[int(0.66*len(data)):]
OrigData=data.copy()
data=OrigData.iloc[trainInd]
test=OrigData.iloc[testInd]
test
filename = 'Indices.pkl'
if SaveSplits==True:
  with open(filename, 'wb') as file:
    pickle.dump(trainInd, file)
    pickle.dump(testInd, file)
    pickle.dump(data, file)
    pickle.dump(test, file)

#Load the objects from the file
with open(filename, 'rb') as file:
    trainInd = pickle.load(file)
    testInd = pickle.load(file)
    data = pickle.load(file)
    test = pickle.load(file)

data['loan_status'] = data.loan_status.map({'Fully Paid':1, 'Charged Off':0})
OrigDFKeys=list(data.keys())
OrigDFKeys.append('zip_code')
pd.set_option('display.max_columns',100)
data
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0f0d91a6-e9fe-4ca5-a832-72654596d45b'>
#   <div id="fe7d02b0-45e8-4241-9d66-452f363e6dd1" data-root-id="0f0d91a6-e9fe-4ca5-a832-72654596d45b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"ce291187-b603-43a4-ab4b-ace61d1c2a1f":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"0f0d91a6-e9fe-4ca5-a832-72654596d45b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"fef61fc0-7e76-4c16-8455-1b1d820b1f44","attributes":{"plot_id":"0f0d91a6-e9fe-4ca5-a832-72654596d45b","comm_id":"0a6c3d97d54a44dd83a14c705e487848","client_comm_id":"b51aae3b1115406596ffb638eccac9b5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"ce291187-b603-43a4-ab4b-ace61d1c2a1f","roots":{"0f0d91a6-e9fe-4ca5-a832-72654596d45b":"fe7d02b0-45e8-4241-9d66-452f363e6dd1"},"root_ids":["0f0d91a6-e9fe-4ca5-a832-72654596d45b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
#        loan_amnt        term  int_rate  installment grade sub_grade  \
# 9026    19850.25   36 months      7.82       620.45     A        A4
# 4408    23000.50   36 months     11.25       675.82     B        B2
# 5586    12458.32   36 months      6.15       378.45     A        A1
# 10472   12000.00   36 months     17.25       428.65     D        D2
# 983     23500.00   36 months     11.15       687.42     B        B2
# ...          ...         ...       ...          ...   ...       ...
# 1794    22500.50   36 months     11.45       680.25     B        B3
# 9850    10825.50   36 months      7.85       338.42     A        A5
# 8152    11500.00   36 months     17.25       412.36     D        D1
# 213     10200.50   36 months     11.25       335.62     B        B4
# 1473    16892.45   36 months     13.95       489.32     C        C2
#
#                 emp_title emp_length home_ownership  annual_inc  \
# 9026    Financial Analyst    7 years       MORTGAGE    115000.0
# 4408    Financial Analyst    7 years       MORTGAGE    125000.0
# 5586    Financial Analyst    7 years       MORTGAGE     86000.0
# 10472  Operations Manager    7 years       MORTGAGE     65000.0
# 983       Project Manager    7 years       MORTGAGE    125000.0
# ...                   ...        ...            ...         ...
# 1794    Financial Analyst    7 years       MORTGAGE    115000.0
# 9850   Operations Manager    7 years           RENT     58500.0
# 8152   Operations Manager    7 years       MORTGAGE     65000.0
# 213    Operations Manager    7 years       MORTGAGE     65000.0
# 1473   Operations Manager    7 years       MORTGAGE     85000.0
#
#       verification_status   issue_d  loan_status             purpose  \
# 9026      Source Verified  Jun-2023            1  debt_consolidation
# 4408      Source Verified  Jun-2023            1  debt_consolidation
# 5586         Not Verified  Jun-2023            1  debt_consolidation
# 10472     Source Verified  Jun-2023            1  debt_consolidation
# 983       Source Verified  Jun-2023            1  debt_consolidation
# ...                   ...       ...          ...                 ...
# 1794             Verified  Jun-2023            1  debt_consolidation
# 9850         Not Verified  Jun-2023            0         credit_card
# 8152             Verified  Jun-2023            1  debt_consolidation
# 213          Not Verified  Jun-2023            0  debt_consolidation
# 1473      Source Verified  Jun-2023            1  debt_consolidation
#
#                          title    dti earliest_cr_line  open_acc  pub_rec  \
# 9026   Debt Consolidation Loan  16.50         Mar-1994      14.0      0.0
# 4408   Debt Consolidation Loan  17.25         Mar-1994      14.0      0.0
# 5586   Debt Consolidation Loan  13.80         Mar-1997      11.0      0.0
# 10472  Debt Consolidation Loan  16.85         Mar-1998      12.0      1.0
# 983    Debt Consolidation Loan  16.80         Mar-1994      15.0      0.0
# ...                        ...    ...              ...       ...      ...
# 1794   Debt Consolidation Loan  18.20         Mar-1995      15.0      0.0
# 9850   Credit Card Refinancing  19.25         Mar-1999      12.0      0.0
# 8152   Debt Consolidation Loan  16.80         Mar-1998      11.0      1.0
# 213    Debt Consolidation Loan  18.50         Mar-1998      11.0      0.0
# 1473   Debt Consolidation Loan  19.20         Mar-1998      13.0      0.0
#
#        revol_bal  revol_util  total_acc initial_list_status application_type  \
# 9026     28500.0        47.5       32.0                   w       INDIVIDUAL
# 4408     32500.0        55.2       34.0                   w       INDIVIDUAL
# 5586     13500.0        29.5       27.0                   w       INDIVIDUAL
# 10472     8500.0        48.5       28.0                   f       INDIVIDUAL
# 983      35000.0        55.2       35.0                   w       INDIVIDUAL
# ...          ...         ...        ...                 ...              ...
# 1794     30500.0        58.5       35.0                   f       INDIVIDUAL
# 9850     14500.0        42.5       25.0                   w       INDIVIDUAL
# 8152      7500.0        48.5       25.0                   f       INDIVIDUAL
# 213      14500.0        56.2       24.0                   f       INDIVIDUAL
# 1473     18500.0        58.5       28.0                   w       INDIVIDUAL
#
#        mort_acc  pub_rec_bankruptcies  \
# 9026        4.0                   0.0
# 4408        4.0                   0.0
# 5586        2.0                   0.0
# 10472       2.0                   1.0
# 983         4.0                   0.0
# ...         ...                   ...
# 1794        3.0                   0.0
# 9850        1.0                   0.0
# 8152        2.0                   1.0
# 213         2.0                   0.0
# 1473        3.0                   0.0
#
#                                                  address
# 9026    525 Pine Valley Drive\r\nSanta Barbara, CA 70466
# 4408            567 Summit Drive\r\nSacramento, CA 70466
# 5586               123 Palm Street\r\nHonolulu, HI 22690
# 10472         456 Pine Valley Road\r\nBillings, MT 48052
# 983                1234 Oak Street\r\nSan Jose, CA 70466
# ...                                                  ...
# 1794              825 Pine Grove Lane\r\nTulsa, OK 30723
# 9850   851 Mountain View Drive\r\nSalt Lake City, UT ...
# 8152            584 Pine Street\r\nSpringfield, AP 05113
# 213    425 Mountain View Drive\r\nSalt Lake City, UT ...
# 1473              1234 Oak Street\r\nSunnyvale, CA 70466
#
# [7173 rows x 27 columns]

# %%
df = pd.read_csv("lending_club_loan_two_synthetic.csv")
df
# Out:
#        loan_amnt        term  int_rate  installment grade sub_grade  \
# 0       18250.50   36 months     10.85       552.30     B        B2
# 1       17500.00   36 months     11.15       545.25     B        B3
# 2       19500.00   60 months     11.25       575.40     B        B4
# 3       16800.00   36 months     10.65       525.15     B        B1
# 4       18750.00   36 months     10.80       560.45     B        B5
# ...          ...         ...       ...          ...   ...       ...
# 10605   15200.50   36 months     14.85       445.23     C        C3
# 10606   12800.75   36 months     14.55       410.25     C        C2
# 10607   18500.25   60 months     14.95       498.75     C        C4
# 10608   11500.00   36 months     14.25       385.50     C        C1
# 10609   13250.80   60 months     14.75       425.60     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  \
# 0          Project Manager    7 years       MORTGAGE     95000.0
# 1           Senior Analyst    5 years       MORTGAGE     92000.0
# 2      Operations Director    8 years       MORTGAGE    105000.0
# 3       Software Developer    6 years       MORTGAGE     98000.0
# 4         Business Analyst    4 years       MORTGAGE    102000.0
# ...                    ...        ...            ...         ...
# 10605   Operations Manager    7 years           RENT     65000.0
# 10606    Account Executive    4 years       MORTGAGE     72000.0
# 10607      Project Manager    6 years           RENT     85000.0
# 10608        Sales Manager    8 years       MORTGAGE     58000.0
# 10609     Business Analyst    5 years            OWN     68000.0
#
#       verification_status   issue_d  loan_status             purpose  \
# 0         Source Verified  Jun-2014   Fully Paid  debt_consolidation
# 1                Verified  Aug-2014   Fully Paid         credit_card
# 2         Source Verified  May-2014   Fully Paid  debt_consolidation
# 3                Verified  Mar-2014   Fully Paid    home_improvement
# 4         Source Verified  Sep-2014   Fully Paid  debt_consolidation
# ...                   ...       ...          ...                 ...
# 10605     Source Verified  Jun-2013  Charged Off  debt_consolidation
# 10606            Verified  Aug-2013  Charged Off         credit_card
# 10607        Not Verified  Oct-2013  Charged Off  debt_consolidation
# 10608     Source Verified  Sep-2013  Charged Off  debt_consolidation
# 10609            Verified  Dec-2013  Charged Off  debt_consolidation
#
#                          title    dti earliest_cr_line  open_acc  pub_rec  \
# 0      Debt Consolidation Loan  17.25         Mar-1995        13        0
# 1      Credit Card Refinancing  16.80         Sep-1995        12        0
# 2           Debt Consolidation  18.20         Jun-1994        14        0
# 3             Home Improvement  17.90         Jan-1996        15        0
# 4           Debt Consolidation  17.75         Nov-1995        13        1
# ...                        ...    ...              ...       ...      ...
# 10605  Debt Consolidation Loan  18.50         Mar-1999        12        0
# 10606  Credit Card Refinancing  19.80         May-1998        10        0
# 10607       Debt Consolidation  21.20         Jul-1997        13        0
# 10608       Debt Consolidation  17.50         Apr-1999        11        1
# 10609       Debt Consolidation  18.90         Jun-1998        11        0
#
#        revol_bal  revol_util  total_acc initial_list_status application_type  \
# 0        25000.0       54.20         32                   w       INDIVIDUAL
# 1        22500.0       52.50         30                   f       INDIVIDUAL
# 2        27500.0       55.80         35                   w       INDIVIDUAL
# 3        23000.0       51.75         33                   f       INDIVIDUAL
# 4        22600.0       54.90         31                   w       INDIVIDUAL
# ...          ...         ...        ...                 ...              ...
# 10605    16500.0       58.20         25                   f       INDIVIDUAL
# 10606    14200.0       62.50         22                   f       INDIVIDUAL
# 10607    18000.0       65.80         28                   f       INDIVIDUAL
# 10608    12500.0       55.40         23                   f       INDIVIDUAL
# 10609    14500.0       56.80         24                   f       INDIVIDUAL
#
#        mort_acc  pub_rec_bankruptcies                                address  \
# 0             3                     0   123 Oak Street\r\nBillings, MT 48052
# 1             4                     0  456 Pine Avenue\r\nBillings, MT 48052
# 2             3                     0  789 Maple Drive\r\nBillings, MT 48052
# 3             2                     0    321 Elm Court\r\nBillings, MT 48052
# 4             3                     0   567 Birch Lane\r\nBillings, MT 48052
# ...         ...                   ...                                    ...
# 10605         1                     0   123 Oak Street\r\nPortland, ME 86630
# 10606         2                     0   456 Maple Drive\r\nAugusta, ME 86630
# 10607         0                     0      789 Pine Lane\r\nBangor, ME 86630
# 10608         2                     0    321 Elm Court\r\nLewiston, ME 86630
# 10609         1                     1   567 Birch Street\r\nAuburn, ME 86630
#
#        stallment  refinancing  controllment  stillment
# 0            NaN          NaN           NaN        NaN
# 1            NaN          NaN           NaN        NaN
# 2            NaN          NaN           NaN        NaN
# 3            NaN          NaN           NaN        NaN
# 4            NaN          NaN           NaN        NaN
# ...          ...          ...           ...        ...
# 10605        NaN          NaN           NaN        NaN
# 10606        NaN          NaN           NaN        NaN
# 10607        NaN          NaN           NaN        NaN
# 10608        NaN          NaN           NaN        NaN
# 10609        NaN          NaN           NaN        NaN
#
# [10610 rows x 31 columns]

# %% [markdown]
# ## Data Cleaning & Feature Engineering
#
# - **Feature Removal**: Eliminates redundant/low-value features:
#   - `emp_title` (too many unique job titles)
#   - `emp_length` (employment duration)
#   - `title` (duplicate of purpose)
# - **Categorical Handling**:
#   - Converts `term` from text to numeric (36/60 months)
#   - Creates dummy variables for categorical features
#   - Extracts zip code from address field for geospatial analysis
# - **Date Processing**:
#   - Converts `issue_d` and `earliest_cr_line` to year-based numeric features

# %%
# The length of the data
print(f"The Length of the data: {data.shape}")
# Out:
# The Length of the data: (7173, 27)

# %%
# Missing values
for column in data.columns:
    if data[column].isna().sum() != 0:
        missing = data[column].isna().sum()
        portion = (missing / data.shape[0]) * 100
        print(f"'{column}': number of missing values '{missing}' ==> '{portion:.3f}%'")

# %% [markdown]
# Drops employemnt emp_title, emp_length, and title due to lots of unique values

# %%
data.drop('emp_title', axis=1, inplace=True)

# %%
data.drop('emp_length', axis=1, inplace=True)

# %%
data.drop('title', axis=1, inplace=True)

# %% [markdown]
# Drops all rows with na values

# %%
data.dropna(inplace=True)

# %%
term_values = {' 36 months': 36, ' 60 months': 60, '36 months': 36, '60 months': 60}
data['term'] = data.term.map(term_values)

# %%
dummies = ['grade','sub_grade', 'verification_status', 'purpose', 'initial_list_status', 
           'application_type', 'home_ownership']
data = pd.get_dummies(data, columns=dummies, drop_first=False)

# %%
data['zip_code'] = data.address.apply(lambda x: x[-5:])
ZipToStateDF=data.copy()
ZipToStateDF['zip_code'] = ZipToStateDF.address.apply(lambda x: x[-5:])
ZipToStateDF['state'] = ZipToStateDF.address.apply(lambda x: x[-8:-5])

# %%
ZipToState={zipcode:state for (zipcode,state) in ZipToStateDF[['zip_code','state']].values}
ZipToState
# Out:
# {'70466': 'CA ',
#  '22690': 'HI ',
#  '48052': 'MT ',
#  '86630': 'ME ',
#  '29597': 'AE ',
#  '30723': 'OK ',
#  '11650': 'CA ',
#  '00813': 'VT ',
#  '05113': 'AP ',
#  '93700': 'UT '}

# %%
data.zip_code.value_counts()
# Out:
# zip_code
# 70466    1043
# 48052    1034
# 30723    1030
# 22690    1021
# 05113     833
# 29597     808
# 00813     808
# 11650     208
# 86630     204
# 93700     184
# Name: count, dtype: int64

# %%
data = pd.get_dummies(data, columns=['zip_code'], drop_first=False)

# %%
data.drop('address', axis=1, inplace=True)

# %%
data['issue_d'] = pd.to_datetime(data['issue_d'])
data['issue_d'] = data.issue_d.dt.year
# Out:
# /tmp/ipykernel_1415/2345724880.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['issue_d'] = pd.to_datetime(data['issue_d'])

# %%
data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])
data['earliest_cr_line'] = data.earliest_cr_line.dt.year
# Out:
# /tmp/ipykernel_1415/1915473461.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])

# %% [markdown]
# # 🤖 Clustering & Seed Generation
# ## Cluster-based Distribution Analysis
#
# - **Clustering Strategy**:
#   - Uses KMeans (2 clusters) with standardized features
#   - Focuses on key financial metrics (loan amount, interest rate, income, etc.)
# - **Seed Instruction Creation**:
#   - Generates statistical profiles for each cluster
#   - Includes:
#     - Continuous variable distributions (mean, std, skew/kurtosis)
#     - Categorical distributions (proportions)
#     - Key business rules (grade, zip code, loan status)
#   - Applies sampling factor to control output size

# %%
Keys=['grade_A',
 'grade_B',
 'grade_C',
 'grade_D',
 'grade_E',
 'grade_F',
 'grade_G',
 'zip_code_05113',
 'zip_code_11650',
 'zip_code_22690',
 'zip_code_29597',
 'zip_code_30723',
 'zip_code_48052',
 'zip_code_70466',
 'zip_code_86630',
 'zip_code_93700',
 'loan_status']

# %%
from sklearn.cluster import KMeans,DBSCAN
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scalerAll=StandardScaler()
#X_ScaledAll=scaler.fit_transform(data)

ClusteringKeys=[
   'loan_amnt',
    'term',
    'int_rate',
    'annual_inc',
    'dti',
    'earliest_cr_line',
    'mort_acc',
    'pub_rec_bankruptcies'
]

# %%
ContinuousVariables=[
  'loan_amnt', 
  'int_rate',
  'installment',
  'annual_inc',
  'issue_d',
  'dti',
  'earliest_cr_line',
  'open_acc', 
  'pub_rec',
  'revol_bal',
  'revol_util',
  'total_acc',
  'mort_acc',
  'pub_rec_bankruptcies'
]

PrimaryDiscreteVariables=[
  'grade',
  'zip_code',
]
PrimaryBinaryDiscreteVariables=[
  'loan_status'
]

PrimaryBinaryDiscreteDistributionVariables=[
  'term'
]

      
SecondaryDistributionVariables=[
  'sub_grade',
  'verification_status',
  'purpose',
  'initial_list_status',       
  'application_type',
  'home_ownership',
]

DummyVariables={
  'grade': ['A', 'B', 'C', 'D','E', 'F', 'G'],
  'sub_grade':['1', '2', '3', '4', '5'],
  'verification_status': ['Not Verified', 'Source Verified', 'Verified'],
  'purpose':['car', 'credit_card', 'debt_consolidation', 'educational', 'home_improvement', 'house', 'major_purchase', 'medical', 'moving', 'other','renewable_energy','small_business','vacation', 'wedding'], 
  'initial_list_status': ['f', 'w']  ,       
  'application_type': ['DIRECT_PAY', 'INDIVIDUAL', 'JOINT'],
  'home_ownership': ['RENT','MORTGAGE', 'OWN','ANY', 'NONE', 'OTHER'],
  'zip_code':['00813', '05113', '11650', '22690','29597', '30723', '48052', '70466', '86630', '93700'],
  'loan_status':['Charged Off', 'Paid Fully'],
  'term':[36, 60]
}

CorrelationKeys={
    'mort_acc':['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc','pub_rec_bankruptcies'],
#    'mort_acc':['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'loan_status', 'dti', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc','pub_rec_bankruptcies'],
#    'loan_status':['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'open_acc','pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'mort_acc','pub_rec_bankruptcies']
  }

CorrKeySample=['mort_acc', 'loan_amnt', 'int_rate', 'installment', 'annual_inc', 'loan_status', 'dti', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc','pub_rec_bankruptcies']

# %% [markdown]
# ## 🧠 Key Design Decisions
# 1. **Feature Selection**: Focuses on 8 core clustering variables that best represent loan risk profiles
# 2. **Cluster Replication**: Uses sampling factor to balance representativeness and output size
# 3. **Statistical Depth**: Captures both central tendencies and distribution shape (skew/kurtosis)
# 4. **Business Context**: Preserves key categorical relationships (grade-sub_grade, zip_code-state)

# %%
GroupsIter=iter(data.groupby(Keys))
print(len(data))
import numpy as np
lens=[]
lens_cluster=[]
FinalSeeds=[]
CurrentSeed=[]
NumOfClusters=2
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
SamplingFactor=20
AllDFLen=[]
for name,df2 in GroupsIter:
    
    if len(df2)<=SamplingFactor/2:
        continue

    X_Scaled=scaler.fit_transform(df2[ClusteringKeys])
    print(X_Scaled)
    X_ScaledAll=scaler.fit_transform(df2)
    #print(X_ScaledAll)
    kmeans=KMeans(n_clusters=NumOfClusters,n_init='auto',random_state=42)
    kmeans.fit(X_ScaledAll)
    
    labels=kmeans.labels_

    for ClusterInd in range(0,NumOfClusters):
        CurrentSeed=[]

        Ind=np.where(kmeans.labels_==ClusterInd)[0]
        ClusterRep=len(Ind)
        df=df2.iloc[Ind]
        CurrGrade='A'
        for key in OrigDFKeys:
            if key in ContinuousVariables:
                m=round(df[key].mean(numeric_only=True),2)
                s=round(df[key].std(numeric_only=True),2)
                kur=round(df[key].kurtosis(numeric_only=True),2)
                skewn=round(df[key].skew(numeric_only=True),2)
                mystr=f'{key}: mean={m}, std={s}, kurtosis={kur}, skewness={skewn}'
                #print(mystr)
            elif key in PrimaryDiscreteVariables:
                for SubKey in DummyVariables[key]:
                  if df[key+'_'+SubKey].all():
                      mystr=key+'='+SubKey
                      if key=='grade':
                        CurrGrade=SubKey
                      if key=='zip_code':
                        mystr='address: ' + 'State zipcode'+'='+ZipToState[SubKey]+SubKey


            elif key in PrimaryBinaryDiscreteVariables:
                if df[key].all() and key=="loan_status":
                    mystr=key+'=Fully Paid'
                elif key=="loan_status":
                    mystr=key+'=Charged Off'

                #print(mystr)
            elif key in SecondaryDistributionVariables:
                SecondaryValues=[]
                SecondaryKeys=[]
                for Skey in DummyVariables[key]:
                  if key!='sub_grade':
                    if key+'_'+Skey in df:
                      SecondaryValues.append(df[key+'_'+Skey].sum())
                      SecondaryKeys.append(Skey)
                  else:
                    if key+'_'+CurrGrade+Skey in df:
                      SecondaryValues.append(df[key+'_'+CurrGrade+Skey].sum())
                      SecondaryKeys.append(CurrGrade+Skey)

                      
                mystr=key + ": "+", ".join([k+'='+str(round(val/np.sum(SecondaryValues),2))  for val,k in zip(SecondaryValues,SecondaryKeys)])
            elif key in PrimaryBinaryDiscreteDistributionVariables:
                SecondaryValues=[]
                SecondaryKeys=[]

                for Skey in DummyVariables[key]:
                    SecondaryValues.append(np.sum(df[key]==Skey))
                    SecondaryKeys.append(Skey)
                if key=="term":
                  mystr=key + ": "+", ".join([str(k)+ " months"+'='+str(round(val/np.sum(SecondaryValues),2))  for val,k in zip(SecondaryValues,SecondaryKeys)])
                else:
                  mystr=key + ": "+", ".join([str(k)+'='+str(round(val/np.sum(SecondaryValues),2))  for val,k in zip(SecondaryValues,SecondaryKeys)])
                #print(s)
            else:
                continue

            CurrentSeed.append(mystr)
        
        CurrentSeed.append("\nFollowing are correlations between variables:\n")
        mycorr=df[CorrKeySample].corr(numeric_only=True)
        for key in CorrelationKeys.keys():
          for CorrKey in CorrelationKeys[key]:
            mystr='corr('+key+ ","+CorrKey +")="  + str(round(mycorr[key].drop(key)[CorrKey],2) )
            CurrentSeed.append(mystr)
        AllDFLen.append(ClusterRep)
        for RepCount in range(0,int(ClusterRep/SamplingFactor)):
            FinalSeeds.append(CurrentSeed)

        AllDFLen.append(ClusterRep)

        for RepCount in range(0,int(ClusterRep/SamplingFactor)):
            FinalSeeds.append(CurrentSeed)

    lens.append(len(df))
# Out:
# 7173
# [[-0.50452346  0.          0.50555839 -0.43991095  1.15121486  0.62317695
#   -0.61545745  0.        ]
#  [-0.6679117   0.          0.50555839 -0.58741241 -0.0335771   0.62317695
#   -0.61545745  0.        ]
#  [ 1.74291409  0.         -1.40869182  1.81475423 -1.28072653 -1.80721316
#    1.78482662  0.        ]
#  [ 1.74291409  0.         -1.40869182  1.81475423 -1.28072653 -1.80721316
#    1.78482662  0.        ]
#  [-0.44869093  0.          1.78172519 -0.45255393  0.4029252   0.62317695
#   -0.61545745  0.        ]
#  [-0.50342763  0.          0.50555839 -0.56634077 -0.09593457  0.62317695
#   -0.61545745  0.        ]
#  [-0.50343859  0.          0.50555839 -0.39776767  0.4029252   0.62317695
#   -0.61545745  0.        ]
#  [ 1.96208007  0.         -1.40869182  1.81475423  0.34056773 -1.80721316
#    1.78482662  0.        ]
#  [-0.74998936  0.         -1.40869182 -0.71384223 -0.96893918  0.21811193
#    0.        ]
#  [ 1.3118039  -0.11744404  0.52617264 ... -1.28512186  1.37198868
#    0.        ]]
# [[ 0.01678157  0.         -1.47599873 ... -0.38565424  0.56990028
#    0.        ]
#  [ 0.73759385  0.          1.39053631 ... -0.38565424  0.56990028
#    0.        ]
#  [-1.53911184  0.          0.29190834 ...  1.69352515 -1.75469296
#    0.        ]
#  ...
#  [-1.35606933  0.          0.50658277 ...  2.21332    -1.75469296
#    0.        ]
#  [ 0.73530582  0.          0.12774554 ... -0.90544909  0.56990028
#    0.        ]
#  [ 0.13103671  0.         -1.6022778  ... -0.38565424  0.56990028
#    0.        ]]

# %%
random.shuffle(FinalSeeds)
FinalSeeds[0:5]
# Out:
# [['loan_amnt: mean=20222.42, std=4424.62, kurtosis=-0.1, skewness=1.23',
#   'term: 36 months=0.0, 60 months=1.0',
#   'int_rate: mean=20.51, std=0.46, kurtosis=-0.15, skewness=1.16',
#   'installment: mean=582.65, std=132.69, kurtosis=-0.29, skewness=1.24',
#   'grade=E',
#   'sub_grade: E1=0.64, E2=0.34, E3=0.02, E4=0.0',
#   'home_ownership: RENT=0.32, MORTGAGE=0.68, OWN=0.0',
#   'annual_inc: mean=82295.45, std=19428.86, kurtosis=-0.12, skewness=1.28',
#   'verification_status: Not Verified=0.0, Source Verified=0.64, Verified=0.36',
#   'issue_d: mean=2023.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'loan_status=Fully Paid',
#   'purpose: car=0.0, credit_card=0.0, debt_consolidation=1.0, home_improvement=0.0, house=0.0, major_purchase=0.0, moving=0.0, other=0.0, small_business=0.0',
#   'dti: mean=20.29, std=0.93, kurtosis=-1.18, skewness=0.12',
#   'earliest_cr_line: mean=1998.84, std=1.8, kurtosis=-1.01, skewness=-0.32',
#   'open_acc: mean=12.57, std=1.5, kurtosis=-0.04, skewness=1.18',
#   'pub_rec: mean=0.14, std=0.35, kurtosis=2.95, skewness=2.19',
#   'revol_bal: mean=19195.02, std=7932.5, kurtosis=-0.44, skewness=0.76',
#   'revol_util: mean=62.71, std=5.96, kurtosis=2.1, skewness=-1.82',
#   'total_acc: mean=28.09, std=4.38, kurtosis=-1.22, skewness=0.69',
#   'initial_list_status: f=0.23, w=0.77',
#   'application_type: INDIVIDUAL=1.0',
#   'mort_acc: mean=1.59, std=1.17, kurtosis=-1.36, skewness=-0.41',
#   'pub_rec_bankruptcies: mean=0.14, std=0.35, kurtosis=2.95, skewness=2.19',
#   'address: State zipcode=HI 22690',
#   '\nFollowing are correlations between variables:\n',
#   'corr(mort_acc,loan_amnt)=0.56',
#   'corr(mort_acc,int_rate)=0.56',
#   'corr(mort_acc,installment)=0.55',
#   'corr(mort_acc,annual_inc)=0.77',
#   'corr(mort_acc,dti)=-0.78',
#   'corr(mort_acc,open_acc)=0.75',
#   'corr(mort_acc,pub_rec)=0.14',
#   'corr(mort_acc,revol_bal)=0.62',
#   'corr(mort_acc,revol_util)=0.12',
#   'corr(mort_acc,total_acc)=0.84',
#   'corr(mort_acc,pub_rec_bankruptcies)=0.14'],
#  ['loan_amnt: mean=10984.83, std=677.24, kurtosis=-0.95, skewness=0.71',
#   'term: 36 months=1.0, 60 months=0.0',
#   'int_rate: mean=14.3, std=0.74, kurtosis=-1.18, skewness=0.92',
#   'installment: mean=356.47, std=17.4, kurtosis=-1.69, skewness=0.41',
#   'grade=C',
#   'sub_grade: C1=0.69, C2=0.01, C3=0.0, C4=0.14, C5=0.15',
#   'home_ownership: RENT=1.0, MORTGAGE=0.0, OWN=0.0',
#   'annual_inc: mean=60160.22, std=2147.98, kurtosis=-0.03, skewness=1.09',
#   'verification_status: Not Verified=0.58, Source Verified=0.42, Verified=0.0',
#   'issue_d: mean=2023.02, std=0.15, kurtosis=39.9, skewness=6.4',
#   'loan_status=Fully Paid',
#   'purpose: car=0.0, credit_card=0.0, debt_consolidation=1.0, home_improvement=0.0, house=0.0, major_purchase=0.0, moving=0.0, other=0.0, small_business=0.0',
#   'dti: mean=17.09, std=0.34, kurtosis=1.23, skewness=1.3',
#   'earliest_cr_line: mean=2000.48, std=0.5, kurtosis=-2.04, skewness=0.07',
#   'open_acc: mean=10.28, std=0.45, kurtosis=-1.06, skewness=0.98',
#   'pub_rec: mean=0.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'revol_bal: mean=10507.27, std=398.2, kurtosis=-0.81, skewness=0.68',
#   'revol_util: mean=56.59, std=1.31, kurtosis=-1.03, skewness=0.38',
#   'total_acc: mean=21.15, std=0.36, kurtosis=1.9, skewness=1.96',
#   'initial_list_status: f=1.0, w=0.0',
#   'application_type: INDIVIDUAL=1.0',
#   'mort_acc: mean=0.29, std=0.46, kurtosis=-1.18, skewness=0.92',
#   'pub_rec_bankruptcies: mean=0.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'address: State zipcode=CA 70466',
#   '\nFollowing are correlations between variables:\n',
#   'corr(mort_acc,loan_amnt)=0.94',
#   'corr(mort_acc,int_rate)=1.0',
#   'corr(mort_acc,installment)=0.82',
#   'corr(mort_acc,annual_inc)=0.91',
#   'corr(mort_acc,dti)=0.8',
#   'corr(mort_acc,open_acc)=-0.18',
#   'corr(mort_acc,pub_rec)=nan',
#   'corr(mort_acc,revol_bal)=0.93',
#   'corr(mort_acc,revol_util)=0.9',
#   'corr(mort_acc,total_acc)=0.59',
#   'corr(mort_acc,pub_rec_bankruptcies)=nan'],
#  ['loan_amnt: mean=20892.72, std=600.19, kurtosis=-1.31, skewness=0.06',
#   'term: 36 months=1.0, 60 months=0.0',
#   'int_rate: mean=7.89, std=0.04, kurtosis=-1.49, skewness=0.22',
#   'installment: mean=642.45, std=16.39, kurtosis=-1.15, skewness=0.49',
#   'grade=A',
#   'sub_grade: A1=0.0, A2=0.0, A3=0.0, A4=0.8, A5=0.2',
#   'home_ownership: RENT=0.0, MORTGAGE=1.0, OWN=0.0',
#   'annual_inc: mean=120873.28, std=3823.94, kurtosis=-1.27, skewness=-0.25',
#   'verification_status: Not Verified=0.0, Source Verified=1.0, Verified=0.0',
#   'issue_d: mean=2023.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'loan_status=Fully Paid',
#   'purpose: car=0.0, credit_card=0.0, debt_consolidation=1.0, home_improvement=0.0, house=0.0, major_purchase=0.0, moving=0.0, other=0.0, small_business=0.0',
#   'dti: mean=16.74, std=0.16, kurtosis=30.69, skewness=-5.11',
#   'earliest_cr_line: mean=1993.78, std=0.47, kurtosis=0.13, skewness=-0.68',
#   'open_acc: mean=13.09, std=0.29, kurtosis=7.26, skewness=2.99',
#   'pub_rec: mean=0.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'revol_bal: mean=31427.61, std=535.5, kurtosis=-1.7, skewness=0.27',
#   'revol_util: mean=48.09, std=0.48, kurtosis=-1.95, skewness=-0.35',
#   'total_acc: mean=32.24, std=0.43, kurtosis=-0.51, skewness=1.23',
#   'initial_list_status: f=0.0, w=1.0',
#   'application_type: INDIVIDUAL=1.0',
#   'mort_acc: mean=4.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'pub_rec_bankruptcies: mean=0.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'address: State zipcode=OK 30723',
#   '\nFollowing are correlations between variables:\n',
#   'corr(mort_acc,loan_amnt)=nan',
#   'corr(mort_acc,int_rate)=nan',
#   'corr(mort_acc,installment)=nan',
#   'corr(mort_acc,annual_inc)=nan',
#   'corr(mort_acc,dti)=nan',
#   'corr(mort_acc,open_acc)=nan',
#   'corr(mort_acc,pub_rec)=nan',
#   'corr(mort_acc,revol_bal)=nan',
#   'corr(mort_acc,revol_util)=nan',
#   'corr(mort_acc,total_acc)=nan',
#   'corr(mort_acc,pub_rec_bankruptcies)=nan'],
#  ['loan_amnt: mean=11574.84, std=1980.83, kurtosis=-1.26, skewness=0.64',
#   'term: 36 months=1.0, 60 months=0.0',
#   'int_rate: mean=7.31, std=0.8, kurtosis=-0.41, skewness=-1.16',
#   'installment: mean=356.05, std=54.45, kurtosis=-1.27, skewness=0.6',
#   'grade=A',
#   'sub_grade: A1=0.22, A2=0.0, A3=0.0, A4=0.78, A5=0.0',
#   'home_ownership: RENT=0.6, MORTGAGE=0.24, OWN=0.16',
#   'annual_inc: mean=79523.64, std=8990.27, kurtosis=-0.97, skewness=0.71',
#   'verification_status: Not Verified=0.95, Source Verified=0.05, Verified=0.0',
#   'issue_d: mean=2023.01, std=0.1, kurtosis=101.0, skewness=10.05',
#   'loan_status=Fully Paid',
#   'purpose: car=0.0, credit_card=0.0, debt_consolidation=1.0, home_improvement=0.0, house=0.0, major_purchase=0.0, moving=0.0, other=0.0, small_business=0.0',
#   'dti: mean=14.81, std=0.83, kurtosis=0.28, skewness=-0.81',
#   'earliest_cr_line: mean=1998.38, std=1.77, kurtosis=-1.61, skewness=-0.41',
#   'open_acc: mean=11.24, std=0.55, kurtosis=-0.27, skewness=0.06',
#   'pub_rec: mean=0.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'revol_bal: mean=13081.93, std=2847.89, kurtosis=-1.09, skewness=0.74',
#   'revol_util: mean=36.99, std=5.06, kurtosis=-0.62, skewness=-0.9',
#   'total_acc: mean=25.22, std=1.89, kurtosis=-0.83, skewness=0.89',
#   'initial_list_status: f=0.84, w=0.16',
#   'application_type: INDIVIDUAL=1.0',
#   'mort_acc: mean=1.38, std=0.49, kurtosis=-1.77, skewness=0.52',
#   'pub_rec_bankruptcies: mean=0.0, std=0.0, kurtosis=0.0, skewness=0.0',
#   'address: State zipcode=CA 70466',
#   '\nFollowing are correlations between variables:\n',
#   'corr(mort_acc,loan_amnt)=0.96',
#   'corr(mort_acc,int_rate)=-0.83',
#   'corr(mort_acc,installment)=0.96',
#   'corr(mort_acc,annual_inc)=0.93',
#   'corr(mort_acc,dti)=-0.4',
#   'corr(mort_acc,open_acc)=0.75',
#   'corr(mort_acc,pub_rec)=nan',
#   'corr(mort_acc,revol_bal)=0.95',
#   'corr(mort_acc,revol_util)=-0.85',
#   'corr(mort_acc,total_acc)=0.89',
#   'corr(mort_acc,pub_rec_bankruptcies)=nan'],
#  ['loan_amnt: mean=10881.35, std=509.34, kurtosis=0.09, skewness=0.25',
#   'term: 36 months=1.0, 60 months=0.0',
#   'int_rate: mean=11.21, std=0.84, kurtosis=-1.33, skewness=0.09',
#   'installment: mean=347.38, std=13.13, kurtosis=-0.4, skewness=0.13',
#   'grade=B',
#   'sub_grade: B1=0.0, B2=0.22, B3=0.18, B4=0.6, B5=0.0',
#   'home_ownership: RENT=0.36, MORTGAGE=0.64, OWN=0.0',
#   'annual_inc: mean=66683.83, std=2365.07, kurtosis=-0.69, skewness=-0.36',
#   'verification_status: Not Verified=0.84, Source Verified=0.16, Verified=0.0',
#   'issue_d: mean=2023.02, std=0.15, kurtosis=40.95, skewness=6.53',
#   'loan_status=Fully Paid',
#   'purpose: car=0.0, credit_card=0.0, debt_consolidation=1.0, home_improvement=0.0, house=0.0, major_purchase=0.0, moving=0.0, other=0.0, small_business=0.0',
#   'dti: mean=16.56, std=0.59, kurtosis=2.1, skewness=-1.75',
#   'earliest_cr_line: mean=1998.77, std=1.21, kurtosis=-0.77, skewness=-0.26',
#   'open_acc: mean=10.97, std=0.17, kurtosis=27.82, skewness=-5.44',
#   'pub_rec: mean=0.16, std=0.36, kurtosis=1.68, skewness=1.91',
#   'revol_bal: mean=12827.4, std=1948.9, kurtosis=1.13, skewness=-1.56',
#   'revol_util: mean=53.53, std=4.3, kurtosis=-0.33, skewness=-0.65',
#   'total_acc: mean=23.87, std=0.78, kurtosis=0.58, skewness=0.81',
#   'initial_list_status: f=0.71, w=0.29',
#   'application_type: INDIVIDUAL=1.0',
#   'mort_acc: mean=1.34, std=0.47, kurtosis=-1.54, skewness=0.69',
#   'pub_rec_bankruptcies: mean=0.16, std=0.36, kurtosis=1.68, skewness=1.91',
#   'address: State zipcode=MT 48052',
#   '\nFollowing are correlations between variables:\n',
#   'corr(mort_acc,loan_amnt)=0.05',
#   'corr(mort_acc,int_rate)=-0.52',
#   'corr(mort_acc,installment)=-0.04',
#   'corr(mort_acc,annual_inc)=0.35',
#   'corr(mort_acc,dti)=-0.61',
#   'corr(mort_acc,open_acc)=-0.25',
#   'corr(mort_acc,pub_rec)=0.6',
#   'corr(mort_acc,revol_bal)=-0.39',
#   'corr(mort_acc,revol_util)=-0.62',
#   'corr(mort_acc,total_acc)=0.67',
#   'corr(mort_acc,pub_rec_bankruptcies)=0.6']]

# %% [markdown]
# ## 📤 Output Generation
#
# - Exports seed instructions to JSON file
# - Format contains 100+ statistical descriptors per cluster
# - Ready for use with Synthetic Data Generation (SDS) systems

# %%
import json
file_path = "SeedsInstructions.json"

with open(file_path, 'w') as json_file:
    json.dump(FinalSeeds, json_file, indent=4)
